# %%
'''
We decided to go with following dataaset
1) Fine Web EDU
2) 


https://medium.com/@gupta.aman/pre-training-logs-entry-1-training-a-smol-llama-from-scratch-04e4b5d4c5f7

'''
